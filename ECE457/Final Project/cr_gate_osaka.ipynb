# %% [markdown]
# Imports

# %%
# %pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /opt/homebrew/lib/python3.10/site-packages (0.1.4)
# Requirement already satisfied: IPython in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from import-ipynb) (8.14.0)
# Requirement already satisfied: nbformat in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from import-ipynb) (5.9.0)
# Requirement already satisfied: backcall in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: decorator in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (2.15.1)
# Requirement already satisfied: stack-data in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: appnope in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from IPython->import-ipynb) (0.1.3)
# Requirement already satisfied: fastjsonschema in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from nbformat->import-ipynb) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/lib/python3.10/site-packages (from nbformat->import-ipynb) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from nbformat->import-ipynb) (5.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->import-ipynb) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from jupyter-core->nbformat->import-ipynb) (3.5.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from stack-data->IPython->import-ipynb) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from stack-data->IPython->import-ipynb) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/sunil/Library/Python/3.10/lib/python/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->IPython->import-ipynb) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import import_ipynb
from Basic_Operations_Osaka import*
# Out:
# importing Jupyter notebook from Basic_Operations_Osaka.ipynb
# Requirement already satisfied: qiskit in /opt/homebrew/lib/python3.10/site-packages (0.45.1)
# Requirement already satisfied: qiskit-terra==0.45.1 in /opt/homebrew/lib/python3.10/site-packages (from qiskit) (0.45.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (0.13.2)
# Requirement already satisfied: numpy<2,>=1.17 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (1.24.1)
# Requirement already satisfied: ply>=3.10 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (5.9.4)
# Requirement already satisfied: scipy>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (1.10.0)
# Requirement already satisfied: sympy>=1.3 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (1.11.1)
# Requirement already satisfied: dill>=0.3 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (4.1.1)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (0.9.2)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra==0.45.1->qiskit) (4.8.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.45.1->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra==0.45.1->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra==0.45.1->qiskit) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-ibmq-provider in /opt/homebrew/lib/python3.10/site-packages (0.19.2)
# Requirement already satisfied: qiskit-terra>=0.18.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (0.45.1)
# Requirement already satisfied: requests>=2.19 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.1.0)
# Requirement already satisfied: numpy>=1.13 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.24.1)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (2.8.2)
# Requirement already satisfied: websocket-client>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (1.7.0)
# Requirement already satisfied: websockets>=10.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-ibmq-provider) (10.4)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: rustworkx>=0.13.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (3.11)
# Requirement already satisfied: psutil>=5 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.9.4)
# Requirement already satisfied: scipy>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.10.0)
# Requirement already satisfied: sympy>=1.3 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.11.1)
# Requirement already satisfied: dill>=0.3 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (4.1.1)
# Requirement already satisfied: symengine!=0.10.0,>=0.9 in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.9.2)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.10/site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibmq-provider) (2022.12.7)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /opt/homebrew/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /opt/homebrew/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider) (39.0.0)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider) (1.15.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.10/site-packages (from sympy>=1.3->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.2.1)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Qubit 0 has an estimated frequency of 4.822496763471751 GHz.
# Default anharmonicity is -0.30896613792557315 GHz.
# Our updated estimate for the 1->2 transition frequency is 4.513041 +/- 0.00014846898741164327 GHz.
# The transition frequency from |1> to |2> is  4.5130 +/- 1.485e-04
# Pi Amplitude (1->2) = 0.17233418305267548 +/- 0.001510364778300754
# <string>:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <string>:11: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <string>:20: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <string>:22: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# Qubit 1 has an estimated frequency of 4.772693775386564 GHz.
# Default anharmonicity is -0.3102210761952548 GHz.
# Our updated estimate for the 1->2 transition frequency is 4.4630365 +/- 0.00014708606830536266 GHz.
# Pi Amplitude (1->2) = 0.18127759195827067 +/- 0.0011622337974871255
# [4513040960.46839, 4463036478.657935]
# [0.17233418305267548, 0.18127759195827067]
# <string>:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <string>:11: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <string>:20: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# <string>:22: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# Schedule((0, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.03317685418568182, angle=0.023419720628690584, name='CR90p_d0_u2'), DriveChannel(0), name='CR90p_d0_u2')), (0, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.13009522821918773, angle=-2.9240468719207477, name='CR90p_u2'), ControlChannel(2), name='CR90p_u2')), (600, Play(Drag(duration=120, sigma=30, beta=-0.014966562421325243, amp=0.1921823506699478, angle=0.0, name='Xp_d1'), DriveChannel(1), name='Xp_d1')), (720, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.033176854185681816, angle=-3.118172932961103, name='CR90m_d0_u2'), DriveChannel(0), name='CR90m_d0_u2')), (720, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.13009522821918773, angle=0.2175457816690454, name='CR90m_u2'), ControlChannel(2), name='CR90m_u2')), name="ecr")

# %% [markdown]
# Hamiltonian Tomography for the CR Gate

# %%
#Basic Params

backend_config = backend.configuration()
ham_params = backend_config.hamiltonian['vars']
dt = backend_config.dt
print(f'Sampling time: {dt*1e9} ns')
# Out:
# Sampling time: 0.5 ns

# %%
print(backend_config.hamiltonian)
# Out:
# {'description': 'Qubits are modeled as Duffing oscillators. In this case, the system includes higher energy states, i.e. not just |0> and |1>. The Pauli operators are generalized via the following set of transformations:\n\n$(\\mathbb{I}-\\sigma_{i}^z)/2 \\rightarrow O_i \\equiv b^\\dagger_{i} b_{i}$,\n\n$\\sigma_{+} \\rightarrow b^\\dagger$,\n\n$\\sigma_{-} \\rightarrow b$,\n\n$\\sigma_{i}^X \\rightarrow b^\\dagger_{i} + b_{i}$.\n\nQubits are coupled through resonator buses. The provided Hamiltonian has been projected into the zero excitation subspace of the resonator buses leading to an effective qubit-qubit flip-flop interaction. The qubit resonance frequencies in the Hamiltonian are the cavity dressed frequencies and not exactly what is returned by the backend defaults, which also includes the dressing due to the qubit-qubit interactions.\n\nQuantities are returned in angular frequencies, with units 2*pi*GHz.\n\nWARNING: Currently not all system Hamiltonian information is available to the public, missing values have been replaced with 0.\n', 'h_latex': '\\begin{align} \\mathcal{H}/\\hbar = & \\sum_{i=0}^{126}\\left(\\frac{\\omega_{q,i}}{2}(\\mathbb{I}-\\sigma_i^{z})+\\frac{\\Delta_{i}}{2}(O_i^2-O_i)+\\Omega_{d,i}D_i(t)\\sigma_i^{X}\\right) \\\\ & + J_{62,72}(\\sigma_{62}^{+}\\sigma_{72}^{-}+\\sigma_{62}^{-}\\sigma_{72}^{+}) + J_{67,68}(\\sigma_{67}^{+}\\sigma_{68}^{-}+\\sigma_{67}^{-}\\sigma_{68}^{+}) + J_{44,45}(\\sigma_{44}^{+}\\sigma_{45}^{-}+\\sigma_{44}^{-}\\sigma_{45}^{+}) + J_{99,100}(\\sigma_{99}^{+}\\sigma_{100}^{-}+\\sigma_{99}^{-}\\sigma_{100}^{+}) \\\\ & + J_{108,112}(\\sigma_{108}^{+}\\sigma_{112}^{-}+\\sigma_{108}^{-}\\sigma_{112}^{+}) + J_{8,9}(\\sigma_{8}^{+}\\sigma_{9}^{-}+\\sigma_{8}^{-}\\sigma_{9}^{+}) + J_{40,41}(\\sigma_{40}^{+}\\sigma_{41}^{-}+\\sigma_{40}^{-}\\sigma_{41}^{+}) + J_{0,14}(\\sigma_{0}^{+}\\sigma_{14}^{-}+\\sigma_{0}^{-}\\sigma_{14}^{+}) \\\\ & + J_{17,30}(\\sigma_{17}^{+}\\sigma_{30}^{-}+\\sigma_{17}^{-}\\sigma_{30}^{+}) + J_{100,101}(\\sigma_{100}^{+}\\sigma_{101}^{-}+\\sigma_{100}^{-}\\sigma_{101}^{+}) + J_{91,98}(\\sigma_{91}^{+}\\sigma_{98}^{-}+\\sigma_{91}^{-}\\sigma_{98}^{+}) + J_{100,110}(\\sigma_{100}^{+}\\sigma_{110}^{-}+\\sigma_{100}^{-}\\sigma_{110}^{+}) \\\\ & + J_{75,90}(\\sigma_{75}^{+}\\sigma_{90}^{-}+\\sigma_{75}^{-}\\sigma_{90}^{+}) + J_{96,97}(\\sigma_{96}^{+}\\sigma_{97}^{-}+\\sigma_{96}^{-}\\sigma_{97}^{+}) + J_{41,42}(\\sigma_{41}^{+}\\sigma_{42}^{-}+\\sigma_{41}^{-}\\sigma_{42}^{+}) + J_{18,19}(\\sigma_{18}^{+}\\sigma_{19}^{-}+\\sigma_{18}^{-}\\sigma_{19}^{+}) \\\\ & + J_{55,68}(\\sigma_{55}^{+}\\sigma_{68}^{-}+\\sigma_{55}^{-}\\sigma_{68}^{+}) + J_{9,10}(\\sigma_{9}^{+}\\sigma_{10}^{-}+\\sigma_{9}^{-}\\sigma_{10}^{+}) + J_{49,55}(\\sigma_{49}^{+}\\sigma_{55}^{-}+\\sigma_{49}^{-}\\sigma_{55}^{+}) + J_{106,107}(\\sigma_{106}^{+}\\sigma_{107}^{-}+\\sigma_{106}^{-}\\sigma_{107}^{+}) \\\\ & + J_{47,48}(\\sigma_{47}^{+}\\sigma_{48}^{-}+\\sigma_{47}^{-}\\sigma_{48}^{+}) + J_{42,43}(\\sigma_{42}^{+}\\sigma_{43}^{-}+\\sigma_{42}^{-}\\sigma_{43}^{+}) + J_{107,108}(\\sigma_{107}^{+}\\sigma_{108}^{-}+\\sigma_{107}^{-}\\sigma_{108}^{+}) + J_{73,85}(\\sigma_{73}^{+}\\sigma_{85}^{-}+\\sigma_{73}^{-}\\sigma_{85}^{+}) \\\\ & + J_{38,39}(\\sigma_{38}^{+}\\sigma_{39}^{-}+\\sigma_{38}^{-}\\sigma_{39}^{+}) + J_{20,33}(\\sigma_{20}^{+}\\sigma_{33}^{-}+\\sigma_{20}^{-}\\sigma_{33}^{+}) + J_{48,49}(\\sigma_{48}^{+}\\sigma_{49}^{-}+\\sigma_{48}^{-}\\sigma_{49}^{+}) + J_{103,104}(\\sigma_{103}^{+}\\sigma_{104}^{-}+\\sigma_{103}^{-}\\sigma_{104}^{+}) \\\\ & + J_{80,81}(\\sigma_{80}^{+}\\sigma_{81}^{-}+\\sigma_{80}^{-}\\sigma_{81}^{+}) + J_{75,76}(\\sigma_{75}^{+}\\sigma_{76}^{-}+\\sigma_{75}^{-}\\sigma_{76}^{+}) + J_{66,73}(\\sigma_{66}^{+}\\sigma_{73}^{-}+\\sigma_{66}^{-}\\sigma_{73}^{+}) + J_{85,86}(\\sigma_{85}^{+}\\sigma_{86}^{-}+\\sigma_{85}^{-}\\sigma_{86}^{+}) \\\\ & + J_{81,82}(\\sigma_{81}^{+}\\sigma_{82}^{-}+\\sigma_{81}^{-}\\sigma_{82}^{+}) + J_{110,118}(\\sigma_{110}^{+}\\sigma_ ...

# %%
control_qubit = 1
target_qubit = 0
    
inst_sched_map = backend_defaults.instruction_schedule_map 
cr_duration = 600
cr_sigma = 32
cr_square_width = 472
cr_risefall = (cr_duration - cr_square_width) / (2*cr_sigma)

# %%
print(qubit_frequency_data, qubit_pi_pulse_data)
# Out:
# [4513040960.46839, 4463036478.657935] [0.17233418305267548, 0.18127759195827067]

# %% [markdown]
# Pi Pulses for both Qubits

# %%
control_qbit_x12_freq = qubit_frequency_data[control_qubit]
control_qbit_pi_amp_12 = qubit_pi_pulse_data[control_qubit]

with pulse.build(backend) as cq_x12_gate:
    drive_chan = pulse.drive_channel(control_qubit)
    pulse.set_frequency(control_qbit_x12_freq, drive_chan)
    pulse.play(pulse.Gaussian(duration=x12_duration,
                              amp=control_qbit_pi_amp_12,
                              sigma=x12_sigma,
                              name='x12'), drive_chan)
    
target_qbit_x12_freq = qubit_frequency_data[target_qubit]  
target_qbit_pi_amp_12 = qubit_pi_pulse_data[target_qubit]
with pulse.build(backend) as tq_x12_gate:
    drive_chan = pulse.drive_channel(target_qubit)
    pulse.set_frequency(target_qbit_x12_freq, drive_chan)
    pulse.play(pulse.Gaussian(duration=x12_duration,
                              amp=target_qbit_pi_amp_12,
                              sigma=x12_sigma,
                              name='x12'), drive_chan)

# %% [markdown]
# Hadamard gate for both Qubits

# %%
with pulse.build(backend) as cq_h_gate:
    drive_chan = pulse.drive_channel(control_qubit)
    pulse.set_frequency(control_qbit_x12_freq, drive_chan)
    pulse.shift_phase(-np.pi/2, drive_chan)
    pulse.play(pulse.Gaussian(duration=x12_duration,
                              amp=control_qbit_pi_amp_12/2,
                              sigma=x12_sigma,
                              name='h_12'), drive_chan)
    pulse.shift_phase(-np.pi/2, drive_chan)

with pulse.build(backend) as tq_h_gate:
    drive_chan = pulse.drive_channel(target_qubit)
    pulse.set_frequency(target_qbit_x12_freq, drive_chan)
    pulse.shift_phase(-np.pi/2, drive_chan)
    pulse.play(pulse.Gaussian(duration=x12_duration,
                              amp=target_qbit_pi_amp_12/2,
                              sigma=x12_sigma,
                              name='h12'), drive_chan)
    pulse.shift_phase(-np.pi/2, drive_chan)

# %% [markdown]
# Sanity Check with CR Tomography on |0> and |1>

# %%
  
backend_defaults = backend.defaults()
inst_sched_map = backend_defaults.instruction_schedule_map 
cr_pulse = inst_sched_map.get('ecr', (1, 0))
x_gate = inst_sched_map.get('x', (1))
print(cr_pulse)
print(x_gate)
# Out:
# Schedule((0, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.03834986227101661, angle=0.01585074839420244, name='CR90p_d0_u2'), DriveChannel(0), name='CR90p_d0_u2')), (0, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.17084542578828327, angle=-1.9481657444185243, name='CR90p_u2'), ControlChannel(2), name='CR90p_u2')), (600, Play(Drag(duration=120, sigma=30, beta=0.07880295507724727, amp=0.18851344814587007, angle=0.0, name='Xp_d1'), DriveChannel(1), name='Xp_d1')), (720, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.03834986227101661, angle=-3.125741905195591, name='CR90m_d0_u2'), DriveChannel(0), name='CR90m_d0_u2')), (720, Play(GaussianSquare(duration=600, sigma=32, width=472, amp=0.17084542578828327, angle=1.1934269091712688, name='CR90m_u2'), ControlChannel(2), name='CR90m_u2')), name="ecr")
# Schedule((0, Play(Drag(duration=120, sigma=30, beta=0.07880295507724727, amp=0.18851344814587007, angle=0.0, name='Xp_d1'), DriveChannel(1), name='Xp_d1')), name="x")

# %%
def test_cr_pulse(cr_duration, cr_width):
    with pulse.build(backend=backend, name='CR amp sweep') as cr_sched:
        u_chan = pulse.control_channels(control_qubit, target_qubit)[0]
        target_chan = pulse.DriveChannel(target_qubit)
        control_chan = pulse.DriveChannel(control_qubit)
        # pulse.set_frequency(control_qbit_x12_freq, control_chan)
        # pulse.set_frequency(target_qbit_x12_freq, target_chan)
        # pulse.set_frequency(target_qbit_x12_freq, u_chan)
        with pulse.align_sequential():
            with pulse.align_left():
                pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                        amp=0.03834986227101661, angle = 0.018276575418415493,
                                        sigma=cr_sigma, width = cr_width,
                                        name='cr_pulse'), target_chan)
                
                pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                    amp=0.16963801287450686, angle = -1.945739917394311,
                                    sigma=cr_sigma, width = cr_width,
                                    name='cr_pulse'), u_chan)                     
            pulse.call(x_gate)
            with pulse.align_right():
                pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                    amp= -0.03834986227101661, angle = 0.018276575418415493,
                                    sigma=cr_sigma, width = cr_width,
                                    name='cr_pulse'), target_chan)

                pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                    amp=-0.16963801287450686, angle = -1.945739917394311,
                                    sigma=cr_sigma, width = cr_width,
                                    name='cr_pulse'), u_chan)
            # pulse.call(cq_x12_gate)
    return cr_sched

# %%
def build_cr_scheds(qc: int, qt: int, cr_times, phase = 0.0, ZI_MHz = 0.0) -> np.array:
    """Build an array of cross resonance schedules for the Hamiltonian tomography experiment.
    
    Args:
      qc: control qubit index
      qt: target qubit index
      cr_times: array of widths of the cross resonance pulses
      phase: phase offset of the cross resonance pulse (rad)
      ZI_MHz: ZI interaction rate (in MHz) to correct for with frame change
    """
    tomo_circs = []
    
    cr_gate = Gate('cr', num_qubits = 2, params = []) 
    for width in cr_times:
        cr_duration = int(width + 2 * cr_risefall * cr_sigma)
        framechange = 2 * np.pi * int(width) * dt * ZI_MHz * 1e6
        cr_sched = test_cr_pulse(cr_duration, width)
                
        for basis in ['X', 'Y', 'Z']:
            for control in ['0', '1']:
                tomo_circ = QuantumCircuit(2,2)  #use all qubits to avoid error
                if control == '1':
                    tomo_circ.x(qc)# flip control from |0> to |1>
                tomo_circ.append(cr_gate, [qc, qt])  #apply custom cr_gate
                tomo_circ.rz(-framechange, qc)  #apply frame change on the qc
                tomo_circ.barrier(qc, qt)
                if basis == 'X':
                    tomo_circ.h(qt)
                elif basis == 'Y':
                    tomo_circ.sdg(qt)
                    tomo_circ.h(qt)
                tomo_circ.measure(qc,qc)
                tomo_circ.measure(qt,qt)  
                tomo_circ.add_calibration(gate=cr_gate, qubits=[qc, qt], schedule=cr_sched)
                tomo_circs.append(tomo_circ)
                
    tomo_circs_transpiled = transpile(tomo_circs, backend, optimization_level = 1)            
    return tomo_circs_transpiled, schedule(tomo_circs_transpiled, backend)

# %%
cr_times = 16*np.linspace(0,195,16)
print(cr_times)
exp_cr_tomo_circs, cr_scheds = build_cr_scheds(control_qubit, target_qubit, cr_times)
print(len(exp_cr_tomo_circs))
cr_scheds[10].draw()
# Out:
# [   0.  208.  416.  624.  832. 1040. 1248. 1456. 1664. 1872. 2080. 2288.
#  2496. 2704. 2912. 3120.]
# 96

# %%
# cr_tomo_job = backend.run(exp_cr_tomo_circs, meas_level=1, meas_return = 'single', shots = 512)

# %%
cr_gate_freq = 4.4104932608213465*GHz

# %%
sweep_freqs = cr_gate_freq + np.linspace(-30*MHz, 30*MHz, 50)
freq = Parameter('freq')

with pulse.build(backend=backend, name='CR amp sweep') as cr_sched:
    u_chan = pulse.control_channels(control_qubit, target_qubit)[0]
    target_chan = pulse.DriveChannel(target_qubit)
    control_chan = pulse.DriveChannel(control_qubit)
    pulse.set_frequency(control_qbit_x12_freq, control_chan)
    pulse.set_frequency(target_qbit_x12_freq, target_chan)
    pulse.set_frequency(freq, u_chan)
    with pulse.align_sequential():
        with pulse.align_left():
            # pulse.play(pulse.GaussianSquare(duration=cr_duration,
            #                         amp=cr_amp,
            #                         sigma=cr_sigma, width = cr_square_width,
            #                         name='cr_pulse'), target_chan)
                
            pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                amp=cr_amp, angle = 0,
                                sigma=cr_sigma, width = cr_square_width,
                                name='cr_pulse'), u_chan)                     
        pulse.call(cq_x12_gate)
        with pulse.align_right():
            # pulse.play(pulse.GaussianSquare(duration=cr_duration,
            #                     amp= -cr_amp,
            #                     sigma=cr_sigma, width = cr_square_width,
            #                     name='cr_pulse'), target_chan)

            pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                amp= -cr_amp, angle = 0,
                                sigma=cr_sigma, width = cr_square_width,
                                name='cr_pulse'), u_chan)
        pulse.call(cq_x12_gate)

# %%
cr_sweep_gate = Gate('cr_test', 2, [freq])
circ = QuantumCircuit(2,2)
circ.x(control_qubit)
circ.x(target_qubit)
circ.append(cr_sweep_gate, [control_qubit,target_qubit])
circ.measure(control_qubit, control_qubit)
circ.measure(target_qubit,target_qubit)
circ.add_calibration(cr_sweep_gate, (control_qubit,target_qubit), cr_sched, [freq])

exp_cr_sweep_circs = [circ.assign_parameters({freq: f}) for f in sweep_freqs]

# %%
from qiskit import transpile, schedule
cr_test_scheds = schedule(exp_cr_sweep_circs[25], backend)
cr_test_scheds.draw(backend = backend)

# %%
# cr_freq_sweep_job = backend.run(exp_cr_sweep_circs, meas_level=1, meas_return = 'single', shots = 512)

# %%
print(cr_amp)
# Out:
# 0.175

# %%
cr_freq_results = backend.retrieve_job('crt6q857jqmg008zg2s0').result()

# %%
control_expectations = []
target_expectations = []
classifier1 = qubit_classifiers[1]
classifier2 = qubit_classifiers[0]
for i in range(50):
    iq_data0 = cr_freq_results.get_memory(i)[:, target_qubit] * scale_factor
    # if i <= 31:
    iq_data1 = cr_freq_results.get_memory(i)[:, control_qubit] * scale_factor

    val0 = classifier2.predict(reshape_complex_vec(iq_data0))
    val1 = classifier1.predict(reshape_complex_vec(iq_data1))
    control_expectation = 0
    target_expectation = 0
    target_results = [0,0,0]
    control_results = [0,0,0]
    for v in val0:
        if v == 0:
            target_expectation += 1
            target_results[0]+=1
        if v == 1:
            target_expectation += 1
            target_results[1]+=1
        if v == 2:
            target_expectation -= 1
            target_results[2]+=1
    for v in val1:
        if v == 0:
            control_expectation += 1
            control_results[0]+=1
        if v == 1:
            control_expectation += 1
            control_results[1]+=1
        if v == 2:
            control_expectation -= 1
            control_results[2]+=1
    control_expectations.append(control_expectation/512)
    target_expectations.append(target_expectation/512)
    print(sweep_freqs[i]/GHz)
    print(control_results, control_expectation/512)
    print(target_results, target_expectation/512)
    print()
plt.plot(sweep_freqs/GHz, control_expectations, label = 'control qubit')
plt.plot(sweep_freqs/GHz, target_expectations, label = 'target qubit')
plt.xlabel('Freqeucny of the CR Pulse [GHz]')
plt.ylabel('$\\langle Z\\rangle$')
plt.legend()
plt.show()
# Out:
# 4.379881015923387
# [14, 446, 52] 0.796875
# [10, 465, 37] 0.85546875
#
# 4.381105505719306
# [18, 442, 52] 0.796875
# [11, 453, 48] 0.8125
#
# 4.382329995515224
# [17, 449, 46] 0.8203125
# [7, 456, 49] 0.80859375
#
# 4.383554485311143
# [12, 441, 59] 0.76953125
# [12, 471, 29] 0.88671875
#
# 4.384778975107062
# [17, 452, 43] 0.83203125
# [9, 473, 30] 0.8828125
#
# 4.386003464902979
# [14, 439, 59] 0.76953125
# [7, 467, 38] 0.8515625
#
# 4.387227954698897
# [13, 444, 55] 0.78515625
# [12, 460, 40] 0.84375
#
# 4.388452444494816
# [11, 440, 61] 0.76171875
# [9, 465, 38] 0.8515625
#
# 4.389676934290734
# [18, 448, 46] 0.8203125
# [15, 458, 39] 0.84765625
#
# 4.390901424086652
# [19, 457, 36] 0.859375
# [10, 469, 33] 0.87109375
#
# 4.3921259138825715
# [13, 449, 50] 0.8046875
# [13, 456, 43] 0.83203125
#
# 4.39335040367849
# [15, 451, 46] 0.8203125
# [12, 459, 41] 0.83984375
#
# 4.394574893474408
# [23, 443, 46] 0.8203125
# [13, 456, 43] 0.83203125
#
# 4.395799383270327
# [14, 460, 38] 0.8515625
# [15, 454, 43] 0.83203125
#
# 4.397023873066245
# [16, 447, 49] 0.80859375
# [14, 461, 37] 0.85546875
#
# 4.398248362862162
# [18, 446, 48] 0.8125
# [16, 458, 38] 0.8515625
#
# 4.399472852658081
# [17, 458, 37] 0.85546875
# [13, 458, 41] 0.83984375
#
# 4.4006973424539995
# [16, 444, 52] 0.796875
# [8, 465, 39] 0.84765625
#
# 4.401921832249918
# [17, 458, 37] 0.85546875
# [5, 470, 37] 0.85546875
#
# 4.403146322045837
# [17, 444, 51] 0.80078125
# [15, 447, 50] 0.8046875
#
# 4.404370811841755
# [20, 444, 48] 0.8125
# [6, 452, 54] 0.7890625
#
# 4.405595301637673
# [23, 455, 34] 0.8671875
# [11, 466, 35] 0.86328125
#
# 4.406819791433592
# [25, 442, 45] 0.82421875
# [11, 448, 53] 0.79296875
#
# 4.40804428122951
# [18, 443, 51] 0.80078125
# [10, 426, 76] 0.703125
#
# 4.409268771025428
# [21, 440, 51] 0.80078125
# [12, 358, 142] 0.4453125
#
# 4.4104932608213465
# [20, 450, 42] 0.8359375
# [14, 335, 163] 0.36328125
#
# 4.411717750617265
# [22, 454, 36] 0.859375
# [14, 407, 91] 0.64453125
#
# 4.412942240413183
# [20, 456, 36] 0.859375
# [10, 438, 64] 0.75
#
# 4.414166730209102
# [11, 463, 38] 0.8515625
# [7, 452, 53] 0.79296875
#
# 4.41539122000502
# [12, 452, 48] 0.8125
# [15, 449, 48] 0.8125
#
# 4.416615709800938
# [11, 466, 35] 0.86328125
# [9, 465, 38] 0.8515625
#
# 4.417840199596857
# [14, 464, 34] 0.8671875
# [14, 457, 41] 0.83984375
#
# 4.419064689392775
# [14, 470, 28] 0.890625
# [15, 456, 41] 0.83984375
#
# 4.420289179188694
# [23, 458, 31] 0.87890625
# [10, 473, 29] 0.88671875
#
# 4.421513668984613
# [12, 470, 30] 0.8828125
# [12, 461, 39] 0.84765625
#
# 4.42273815878053
# [12, 463, 37] 0.85546875
# [7, 455, 50] 0.8046875
#
# 4.423962648576448
# [12, 464, 36] 0.859375
# [18, 458, 36] 0.859375
#
# 4.425187138372367
# [11, 466, 35] 0.86328125
# [15, 463, 34] 0.8671875
#
# 4.426411628168285
# [10, 474, 28] 0.890625
# [8, 458, 46] 0.8203125
#
# 4.427636117964203
# [14, 467, 31] 0.87890625
# [13, 463, 36] 0.859375
#
# 4.4288606077601225
# [17, 466, 29] 0.88671875
# [17, 465, 30] 0.8828125
#
# 4.430085097556041
# [21, 470, 21] 0.91796875
# [8, 463, 41] 0.83984375
#
# 4.431309587351959
# [15, 462, 35] 0.86328125
# [8, 455, 49] 0.80859375
#
# 4.432534077147878
# [14, 470, 28] 0.890625
# [12, 456, 44] 0.828125
#
# 4.433758566943796
# [15, 473, 24] 0.90625
# [6, 464, 42] 0.8359375
#
# 4.434983056739713
# [17, 472, 23] 0.91015625
# [15, 464, 33] 0.87109375
#
# 4.436207546535632
# [19, 456, 37] 0.85546875
# [15, 450, 47] 0.81640625
#
# 4.4374320363315505
# [15, 471, 26] 0.8984375
# [11, 459, 42] 0.8359375
#
# 4.438656526127469
# [15, 472, 25] 0.90234375
# [11, 467, 34] 0.8671875
#
# 4.439881015923388
# [19, 472, 21] 0.91796875
# [17, 463, 32] 0.875

# %% [markdown]
# CR Gate Tuning

# %%
def cr_pulse_sequence(control_in_two:bool, basis, cr_amp:float, cr_duration, cr_square_width, cr_phase, cancel_amp, cancel_phase):
    with pulse.build(backend=backend, name='CR amp sweep') as cr_sched:
        u_chan = pulse.control_channels(control_qubit, target_qubit)[0]
        target_chan = pulse.DriveChannel(target_qubit)
        control_chan = pulse.DriveChannel(control_qubit)
        pulse.set_frequency(control_qbit_x12_freq, control_chan)
        pulse.set_frequency(target_qbit_x12_freq, target_chan)
        pulse.set_frequency(target_qbit_x12_freq, u_chan)
        with pulse.align_sequential():
            if(control_in_two):
                pulse.call(cq_x12_gate)
            # with pulse.align_left():
            #     pulse.play(pulse.GaussianSquare(duration=cr_duration,
            #                             amp=cancel_amp, angle = cancel_phase,
            #                             sigma=cr_sigma, width = cr_square_width,
            #                             name='cr_pulse'), target_chan)
                
            pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                amp=cr_amp, angle = cr_phase,
                                sigma=cr_sigma, width = cr_square_width,
                                name='cr_pulse'), u_chan)                     
            pulse.call(cq_x12_gate)
            with pulse.align_right():
            #     pulse.play(pulse.GaussianSquare(duration=cr_duration,
            #                         amp= - cancel_amp, angle = cancel_phase,
            #                         sigma=cr_sigma, width = cr_square_width,
            #                         name='cr_pulse'), target_chan)

                pulse.play(pulse.GaussianSquare(duration=cr_duration,
                                    amp=-cr_amp, angle = cr_phase,
                                    sigma=cr_sigma, width = cr_square_width,
                                    name='cr_pulse'), u_chan)
            pulse.call(cq_x12_gate)
            if basis == 'X':
                pulse.call(tq_h_gate)
            elif basis == 'Y':
                pulse.shift_phase(3*np.pi/2, target_chan)
                pulse.call(tq_h_gate)
    return cr_sched

# %%
cr_pulse_sequence(True, 'Z', 1, cr_duration, cr_square_width, 0, 0, 0).draw()

# %%
def build_cr_amp_scheds(qc: int, qt: int, cr_amps, phase = 0.0, ZI_MHz = 0.0) -> np.array:
    """Build an array of cross resonance schedules for the Hamiltonian tomography experiment.
    
    Args:
      qc: control qubit index
      qt: target qubit index
      cr_amps: array of widths of the cross resonance pulses
      phase: phase offset of the cross resonance pulse (rad)
      ZI_MHz: ZI interaction rate (in MHz) to correct for with frame change
    """
    tomo_circs = []
    cr_gate = Gate('CR Pulse', 2, [])
    for cr_amp in cr_amps:
        for basis in ['Z']:
            for control in ['1']:
                control_in_two = False
                if control == '2':
                    control_in_two = True
                # framechange = 2 * np.pi * int(cr_square_width) * dt * ZI_MHz * 1e6
                cr_sched = cr_pulse_sequence(control_in_two, basis, cr_amp, cr_duration, cr_square_width,0,0,0)
                tomo_circ = QuantumCircuit(2, 2) 
                tomo_circ.x(0)
                tomo_circ.x(1)
                tomo_circ.append(cr_gate, [qc, qt])  #apply custom cr_gate
                # tomo_circ.rz(-framechange, qc)  #apply frame change on the qc
                # tomo_circ.barrier(qc, qt)
                # for i in [0,1,2,14]:
                tomo_circ.measure(qc, qc)
                tomo_circ.measure(qt, qt)   
                # tomo_circ.measure_all()
                tomo_circ.add_calibration(cr_gate, (qc, qt), cr_sched, [])
                tomo_circs.append(tomo_circ)
                
                
    tomo_circs_transpiled = transpile(tomo_circs, backend, optimization_level = 1)            
    return tomo_circs_transpiled, schedule(tomo_circs_transpiled, backend=backend)

# %%
cr_amps = np.arange(0,1,0.02)+0.02
exp_cr_amp_circs, cr_scheds = build_cr_amp_scheds(control_qubit, target_qubit, cr_amps)
print(len(exp_cr_amp_circs))
cr_scheds[9].draw()
# Out:
# 50

# %%
# cr_amp_job = backend.run(exp_cr_amp_circs, meas_level=1, meas_return = 'single', shots = 1024)

# %%
cr_amp_results = backend.retrieve_job('crv8n64dbt40008jtpsg').result()
# cr_amp_results2 = backend.retrieve_job('crr3k4ckx9hg0081hfzg').result()
# print(cr_amp_results)

# %%
expectation_vals = np.zeros(len(cr_amps))
for i in range(len(exp_cr_amp_circs)):
    iq_data = cr_amp_results.get_memory(i)[:,control_qubit] * scale_factor
    # iq_data2 = cr_amp_results2.get_memory(i)[:,target_qubit] * scale_factor
    expectation = 0
    results = [0,0]
    for j in range(len(iq_data)):
        v = classify_control(iq_data[j])
        if v == 1:
            expectation += 1
            results[0]+=1
        if v == 2:
            expectation -= 1
            results[1]+=1
    print(cr_amps[i], results, expectation/(1024))
    expectation_vals[i] = expectation/(1024)
    
plt.plot(cr_amps, expectation_vals, marker = 'x', label = 'control')
for i in range(len(exp_cr_amp_circs)):
    iq_data = cr_amp_results.get_memory(i)[:,target_qubit] * scale_factor
    # iq_data2 = cr_amp_results2.get_memory(i)[:,target_qubit] * scale_factor
    expectation = 0
    results = [0,0]
    for j in range(len(iq_data)):
        v = classify_target(iq_data[j])
        if v == 1:
            expectation += 1
            results[0]+=1
        if v == 2:
            expectation -= 1
            results[1]+=1
    print(cr_amps[i], results, expectation/(1024))
    expectation_vals[i] = expectation/(1024)
plt.plot(cr_amps, expectation_vals, marker = 'x', label = 'target')
plt.legend()
plt.show()
# Out:
# 0.02 [867, 157] 0.693359375
# 0.04 [856, 168] 0.671875
# 0.06 [882, 142] 0.72265625
# 0.08 [831, 193] 0.623046875
# 0.1 [848, 176] 0.65625
# 0.12000000000000001 [857, 167] 0.673828125
# 0.13999999999999999 [855, 169] 0.669921875
# 0.16 [848, 176] 0.65625
# 0.18 [886, 138] 0.73046875
# 0.19999999999999998 [855, 169] 0.669921875
# 0.22 [828, 196] 0.6171875
# 0.24 [828, 196] 0.6171875
# 0.26 [802, 222] 0.56640625
# 0.28 [756, 268] 0.4765625
# 0.30000000000000004 [749, 275] 0.462890625
# 0.32 [714, 310] 0.39453125
# 0.34 [651, 373] 0.271484375
# 0.36000000000000004 [598, 426] 0.16796875
# 0.38 [585, 439] 0.142578125
# 0.4 [516, 508] 0.0078125
# 0.42000000000000004 [434, 590] -0.15234375
# 0.44 [380, 644] -0.2578125
# 0.46 [385, 639] -0.248046875
# 0.48000000000000004 [400, 624] -0.21875
# 0.5 [450, 574] -0.12109375
# 0.52 [482, 542] -0.05859375
# 0.54 [525, 499] 0.025390625
# 0.56 [567, 457] 0.107421875
# 0.5800000000000001 [620, 404] 0.2109375
# 0.6 [690, 334] 0.34765625
# 0.62 [700, 324] 0.3671875
# 0.64 [714, 310] 0.39453125
# 0.66 [710, 314] 0.38671875
# 0.68 [736, 288] 0.4375
# 0.7000000000000001 [715, 309] 0.396484375
# 0.7200000000000001 [727, 297] 0.419921875
# 0.74 [750, 274] 0.46484375
# 0.76 [756, 268] 0.4765625
# 0.78 [751, 273] 0.466796875
# 0.8 [796, 228] 0.5546875
# 0.8200000000000001 [795, 229] 0.552734375
# 0.8400000000000001 [809, 215] 0.580078125
# 0.86 [826, 198] 0.61328125
# 0.88 [818, 206] 0.59765625
# 0.9 [788, 236] 0.5390625
# 0.92 [825, 199] 0.611328125
# 0.9400000000000001 [792, 232] 0.546875
# 0.9600000000000001 [788, 236] 0.5390625
# 0.98 [786, 238] 0.53515625
# 1.0 [754, 270] 0.47265625
# 0.02 [769, 255] 0.501953125
# 0.04 [792, 232] 0.546875
# 0.06 [756, 268] 0.4765625
# 0.08 [704, 320] 0.375
# 0.1 [662, 362] 0.29296875
# 0.12000000000000001 [661, 363] 0.291015625
# 0.13999999999999999 [619, 405] 0.208984375
# 0.16 [645, 379] 0.259765625
# 0.18 [641, 383] 0.251953125
# 0.19999999999999998 [646, 378] 0.26171875
# 0.22 [647, 377] 0.263671875
# 0.24 [677, 347] 0.322265625
# 0.26 [651, 373] 0.271484375
# 0.28 [672, 352] 0.3125
# 0.30000000000000004 [653, 371] 0.275390625
# 0.32 [620, 404] 0.2109375
# 0.34 [616, 408] 0.203125
# 0.36000000000000004 [609, 415] 0.189453125
# 0.38 [572, 452] 0.1171875
# 0.4 [561, 463] 0.095703125
# 0.42000000000000004 [599, 425] 0.169921875
# 0.44 [579, 445] 0.130859375
# 0.46 [562, 462] 0.09765625
# 0.48000000000000004 [539, 485] 0.052734375
# 0.5 [519, 505] 0.013671875
# 0.52 [516, 508] 0.0078125
# 0.54 [477, 547] -0.068359375
# 0.56 [445, 579] -0.130859375
# 0.5800000000000001 [449, 575] -0.123046875
# 0.6 [425, 599] -0.169921875
# 0.62 [430, 594] -0.16015625
# 0.64 [393, 631] -0.232421875
# 0.66 [387, 637] -0.244140625
# 0.68 [385, 639] -0.248046875
# 0.7000000000000001 [375, 649] -0.267578125
# 0.7200000000000001 [405, 619] -0.208984375
# 0.74 [404, 620] -0.2109375
# 0.76 [404, 620] -0.2109375
# 0.78 [454, 570] -0.11328125
# 0.8 [481, 543] -0.060546875
# 0.8200000000000001 [481, 543] -0.060546875
# 0.8400000000000001 [477, 547] -0.068359375
# 0.86 [477, 547] -0.068359375
# 0.88 [496, 528] -0.03125
# 0.9 [525, 499] 0.025390625
# 0.92 [517, 507] 0.009765625
# 0.9400000000000001 [497, 527] -0.029296875
# 0.9600000000000001 [524, 500] 0.0234375
# 0.98 [510, 514] -0.00390625
# 1.0 [550, 474] 0.07421875

# %%
cr_amp = 0.58 # or 0.175?
print(cr_amp) #induces pi/2 rotation supposedly
# Out:
# 0.58

# %% [markdown]
# Sanity Check for Amplitudes

# %%
cr_gate = Gate('CR Pulse', 2, [])
cr_sched1 = cr_pulse_sequence(False, 'Z', cr_amp, cr_duration, cr_square_width, 0.0,0,0)
tomo_circ1 = QuantumCircuit(2, 2) 
tomo_circ1.x(0)
tomo_circ1.x(1)
tomo_circ1.append(cr_gate, [control_qubit, target_qubit])  #apply custom cr_gate
# tomo_circ.rz(-framechange, qc)  #apply frame change on the qc
# tomo_circ.barrier(qc, qt)
# for i in [0,1,2,14]:
tomo_circ1.measure(control_qubit, control_qubit)
tomo_circ1.measure(target_qubit, target_qubit)   
# tomo_circ.measure_all()
tomo_circ1.add_calibration(cr_gate, (control_qubit, target_qubit), cr_sched1, [])
schedule(tomo_circ1, backend).draw()

# %%
cr_gate = Gate('CR Pulse', 2, [])
cr_sched2 = cr_pulse_sequence(False, 'Z', 0.28, cr_duration, cr_square_width, 0.0)
tomo_circ2 = QuantumCircuit(2, 2) 
tomo_circ2.x(0)
tomo_circ2.x(1)
tomo_circ2.append(cr_gate, [control_qubit, target_qubit])  #apply custom cr_gate
# tomo_circ.rz(-framechange, qc)  #apply frame change on the qc
# tomo_circ.barrier(qc, qt)
# for i in [0,1,2,14]:
tomo_circ2.measure(control_qubit, control_qubit)
tomo_circ2.measure(target_qubit, target_qubit)   
# tomo_circ.measure_all()
tomo_circ2.add_calibration(cr_gate, (control_qubit, target_qubit), cr_sched2, [])

# %%
# cr_amp_check = backend.run(tomo_circ1, meas_level=1, meas_return = 'single', shots = 2048)

# %%
amp_check_results = backend.retrieve_job('crv2ra1y7jt0008064y0').result()

# %%
classifier = qubit_classifiers[target_qubit]
for i in range(1):
    iq_data = amp_check_results.get_memory(i)[:,target_qubit] * scale_factor
    val = classifier.predict(reshape_complex_vec(iq_data))

    expectation = 0
    results = [0,0,0]
    for v in val:
        if v == 0:
            expectation += 1
            results[0]+=1
        if v == 1:
            expectation += 1
            results[1]+=1
        if v == 2:
            expectation -= 1
            results[2]+=1
    print(results)
# Out:
# [25, 1083, 940]

# %%
IBMQ.save_account('6c6a7f242a6e15d4ff69f3b5ddb95efada40b2a822012af5516515ecab99ef9458f4fe1bc7cafcdd199da533de1103350d5202d5acde3c2a83268fbf41171dbf', overwrite=True)
IBMQ.load_account()

# get backend
provider = IBMQ.get_provider(hub='ibm-q')
backend = provider.get_backend('ibm_brisbane')
backend_defaults = backend.defaults()
# Out:
# ibmqfactory.load_account:WARNING:2024-05-03 16:37:55,450: Credentials are already in use. The existing account in the session will be replaced.

# %%
def build_cr_tomo_scheds(qc: int, qt: int, cr_times, phase, cancellation_amp, cancellation_phase, ZI_MHz = 0.0) -> np.array:
    """Build an array of cross resonance schedules for the Hamiltonian tomography experiment.
    
    Args:
      qc: control qubit index
      qt: target qubit index
      cr_amps: array of widths of the cross resonance pulses
      phase: phase offset of the cross resonance pulse (rad)
      ZI_MHz: ZI interaction rate (in MHz) to correct for with frame change
    """
    tomo_circs = []
    cr_gate = Gate('CR Pulse', 2, [])
    # for cr_phase in cr_phases:
    for width in cr_times:
        cr_duration = int(width + 2 * cr_risefall * cr_sigma)
        # print(cr_duration % 16)
        for basis in ['X','Y','Z']:
            for control in ['1', '2']:
                control_in_two = False
                if control == '2':
                    control_in_two = True
                # framechange = 2 * np.pi * int(cr_square_width) * dt * ZI_MHz * 1e6
                cr_sched = cr_pulse_sequence(control_in_two, basis, cr_amp, cr_duration, width, phase, cancellation_amp, cancellation_phase)
                tomo_circ = QuantumCircuit(2, 2) 
                tomo_circ.x(qc)
                tomo_circ.x(qt)
                tomo_circ.append(cr_gate, [qc, qt])  #apply custom cr_gate
                # tomo_circ.rz(-framechange, qc)  #apply frame change on the qc
                # tomo_circ.barrier(qc, qt)
                # for i in range(127):
                tomo_circ.measure(qc, qc)
                tomo_circ.measure(qt, qt)  
                # tomo_circ.measure_all()
                tomo_circ.add_calibration(cr_gate, (qc, qt), cr_sched, [])
                tomo_circs.append(tomo_circ)
                
                
    # tomo_circs_transpiled = transpile(tomo_circs, backend, optimization_level = 1)            
    return tomo_circs, schedule(tomo_circs, backend=backend)

# %%
print(cr_amp)
# Out:
# 0.175

# %%
cr_times = 16*np.linspace(0,120,21)
print(cr_times+cr_risefall*2*cr_sigma)
exp_cr_tomo_circs, cr_scheds = build_cr_tomo_scheds(control_qubit, target_qubit, cr_times, 0,0,0)
print(len(exp_cr_tomo_circs))
cr_scheds[29].draw()
# Out:
# [ 128.  224.  320.  416.  512.  608.  704.  800.  896.  992. 1088. 1184.
#  1280. 1376. 1472. 1568. 1664. 1760. 1856. 1952. 2048.]
# 126

# %%
cr_tomo_job_ids = []

# %%
# cr_tomo_job = backend.run(exp_cr_tomo_circs, meas_level=1, meas_return = 'single', shots = 1024)
# cr_tomo_job_ids.append(cr_tomo_job.job_id())
# job_monitor(cr_tomo_job)

# %%
cr_tomo_results = backend.retrieve_job('crr42ahx484g008eyetg').result()
cr_tomo_results2 = backend.retrieve_job('crr429h7wv80008f20fg').result()

# %%
iq_data = cr_tomo_results.get_memory(29)[:,target_qubit] * scale_factor
iq_data2 = cr_tomo_results2.get_memory(29)[:,control_qubit] * scale_factor

plt.scatter(np.real(iq_data), np.imag(iq_data))
# plt.scatter(np.real(iq_data2), np.imag(iq_data2))
plt.show()

# %%
avg_t_c = np.zeros((6,len(cr_times)), dtype = complex)
cr_amp_data = []
# iq_data = cr_amp_results.get_memory(0)[:,2] * scale_factor
# print(iq_data)
classifier = qubit_classifiers[control_qubit]
expectation_vals = np.zeros((6, len(cr_times)))
for i in range(126):
    iq_data = cr_tomo_results.get_memory(i)[:,control_qubit] * scale_factor
    iq_data2 = cr_tomo_results2.get_memory(i)[:,control_qubit] * scale_factor
    val = classifier.predict(reshape_complex_vec(iq_data))
    val2 = classifier.predict(reshape_complex_vec(iq_data2))

    expectation = 0
    results = [0,0,0]
    for v in val:
        if v == 0:
            expectation += 1
            results[0]+=1
        if v == 1:
            expectation += 1
            results[1]+=1
        if v == 2:
            expectation -= 1
            results[2]+=1
    for v in val2:
        if v == 0:
            expectation += 1
            results[0]+=1
        if v == 1:
            expectation += 1
            results[1]+=1
        if v == 2:
            expectation -= 1
            results[2]+=1
    # if i % 2 == 0:
    print(i//6, results, expectation/(1536*2))
    expectation_vals[i%6, i//6] = expectation/(1536*2)
    avg_t_c[i%6, i//6] = 1-sum(val)/1024
# Out:
# 0 [59, 487, 2526] -0.64453125
# 0 [95, 2039, 938] 0.3893229166666667
# 0 [62, 501, 2509] -0.6334635416666666
# 0 [84, 2068, 920] 0.4010416666666667
# 0 [75, 487, 2510] -0.6341145833333334
# 0 [100, 2022, 950] 0.3815104166666667
# 1 [57, 489, 2526] -0.64453125
# 1 [81, 1930, 1061] 0.3092447916666667
# 1 [66, 566, 2440] -0.5885416666666666
# 1 [101, 2000, 971] 0.3678385416666667
# 1 [61, 527, 2484] -0.6171875
# 1 [103, 1981, 988] 0.3567708333333333
# 2 [59, 526, 2487] -0.619140625
# 2 [108, 1989, 975] 0.365234375
# 2 [91, 522, 2459] -0.6009114583333334
# 2 [110, 1951, 1011] 0.341796875
# 2 [55, 517, 2500] -0.6276041666666666
# 2 [104, 1953, 1015] 0.3391927083333333
# 3 [76, 542, 2454] -0.59765625
# 3 [94, 2036, 942] 0.38671875
# 3 [57, 509, 2506] -0.6315104166666666
# 3 [82, 1995, 995] 0.3522135416666667
# 3 [61, 532, 2479] -0.6139322916666666
# 3 [86, 1997, 989] 0.3561197916666667
# 4 [62, 489, 2521] -0.6412760416666666
# 4 [106, 2020, 946] 0.3841145833333333
# 4 [57, 522, 2493] -0.623046875
# 4 [102, 2055, 915] 0.404296875
# 4 [45, 510, 2517] -0.638671875
# 4 [110, 2021, 941] 0.3873697916666667
# 5 [81, 511, 2480] -0.6145833333333334
# 5 [95, 2070, 907] 0.4095052083333333
# 5 [60, 510, 2502] -0.62890625
# 5 [105, 2090, 877] 0.4290364583333333
# 5 [68, 491, 2513] -0.6360677083333334
# 5 [88, 2112, 872] 0.4322916666666667
# 6 [64, 506, 2502] -0.62890625
# 6 [119, 2082, 871] 0.4329427083333333
# 6 [56, 484, 2532] -0.6484375
# 6 [101, 2087, 884] 0.4244791666666667
# 6 [68, 513, 2491] -0.6217447916666666
# 6 [95, 2072, 905] 0.4108072916666667
# 7 [72, 513, 2487] -0.619140625
# 7 [91, 2096, 885] 0.423828125
# 7 [77, 539, 2456] -0.5989583333333334
# 7 [101, 2101, 870] 0.43359375
# 7 [66, 542, 2464] -0.6041666666666666
# 7 [121, 2063, 888] 0.421875
# 8 [76, 509, 2487] -0.619140625
# 8 [112, 2037, 923] 0.3990885416666667
# 8 [61, 502, 2509] -0.6334635416666666
# 8 [109, 2005, 958] 0.3763020833333333
# 8 [64, 539, 2469] -0.607421875
# 8 [100, 2089, 883] 0.4251302083333333
# 9 [67, 588, 2417] -0.5735677083333334
# 9 [96, 2062, 914] 0.4049479166666667
# 9 [63, 549, 2460] -0.6015625
# 9 [98, 2086, 888] 0.421875
# 9 [64, 562, 2446] -0.5924479166666666
# 9 [97, 2061, 914] 0.4049479166666667
# 10 [84, 510, 2478] -0.61328125
# 10 [103, 2018, 951] 0.380859375
# 10 [71, 502, 2499] -0.626953125
# 10 [99, 2054, 919] 0.4016927083333333
# 10 [74, 478, 2520] -0.640625
# 10 [92, 1970, 1010] 0.3424479166666667
# 11 [75, 589, 2408] -0.5677083333333334
# 11 [108, 2072, 892] 0.4192708333333333
# 11 [61, 596, 2415] -0.572265625
# 11 [104, 2098, 870] 0.43359375
# 11 [67, 567, 2438] -0.5872395833333334
# 11 [95, 2089, 888] 0.421875
# 12 [76, 516, 2480] -0.6145833333333334
# 12 [99, 2030, 943] 0.3860677083333333
# 12 [78, 501, 2493] -0.623046875
# 12 [95, 2067, 910] 0.4075520833333333
# 12 [73, 533, 2466] -0.60546875
# 12 [100, 2008, 964] 0.3723958333333333
# 13 [68, 596, 2408] -0.5677083333333334
# 13 [115, 2078, 879] 0.427734375
# 13 [62, 583, 2427] -0.580078125
# 13 [99, 2092, 881] 0.4264322916666667
# 13 [70, 531, 2471] -0.6087239583333334
# 13 [99, 2076, 897] 0.416015625
# 14 [73, 471, 2528] -0.6458333333333334
# 14 [94, 2018, 960] 0.375
# 14 [63, 544, 2465] -0.6048177083333334
# 14 [111, 2080, 881] 0.4264322916666667
# 14 [81, 465, 2526] -0.64453125
# 14 [127, 2024, 921] 0.400390625
# 15 [72, 533, 2467] -0.6061197916666666
# 15 [105, 2073, 894] 0.41796875
# 15 [57, 597, 2418] -0.57421875
# 15 [112, 2070, 890] 0.4205729166666667
# 15 [80, 583, 2409] -0.568359375
# 15 [97, 2116, 859] 0.4407552083333333
# 16 [64, 464, 2544] -0.65625
# 16 [111, 2023, 938] 0.3893229166666667
# 16 [63, 491, 2518] -0.6393229166666666
# 16 [115, 2043, 914] 0.4049479166666667
# 16 [68, 496, 2508] -0.6328125
# 16 [92, 2009, 971] 0.3678385416666667
# 17 [75, 602, 2395] -0.5592447916666666
# 17 [119, 2053, 900] 0.4140625
# 17 [93, 578, 2401] -0.5631510416666666
# 17 [120, 2027, 925] 0.3977864583333333
# 17 [84, 570, 2418] -0.57421875
# 17 [127, 2059, 886] 0.4231770833333333
# 18 [72, 474, 2526] -0.64453125
# 18 [113, 2030, 929] 0.3951822916666667
# 18 [66, 518, 2488] -0.6197916666666666
# 18 [91, 2037, 944] 0.3854166666666667
# 18 [67, 495, 2510] -0.6341145833333334
# 18 [110, 2040, 922] 0.3997395833333333
# 19 [88, 556, 2428] -0.5807291666666666
# 19 [111, 2046, 915] 0.404296875
# 19 [63, 597, 2412] -0.5703125
# 19 [107, 2070, 895] 0.4173177083333333
# 19 [84, 617, 2371] -0.5436197916666666
# 19 [106, 2123, 843] 0.451171875
# 20 [49, 473, 2550] -0.66015625
# 20 [106, 2012, 954] 0.37890625
# 20 [102, 500, 2470] -0.6080729166666666
# 20 [117, 2011, 944] 0.3854166666666667
# 20 [80, 492, 2500] -0.6276041666666666
# 20 [103, 2065, 904] 0.4114583333333333

# %%
avg_t_c = expectation_vals

# %%
from scipy.optimize import curve_fit

def get_omega(eDelta, eOmega_x, eOmega_y):
    """Return \Omega from parameter arguments."""
    eOmega = np.sqrt(eDelta**2 + eOmega_x**2 + eOmega_y**2)
    return eOmega

def avg_X(t, eDelta, eOmega_x, eOmega_y, T):
    """Return average X Pauli measurement vs time t"""
    eOmega = get_omega(eDelta, eOmega_x, eOmega_y)
    eXt = (-eDelta*eOmega_x + np.exp(-t/T)*(eDelta*eOmega_x*np.cos(eOmega*t) + \
           eOmega*eOmega_y*np.sin(eOmega*t))) / eOmega**2 
    return eXt

def avg_Y(t, eDelta, eOmega_x, eOmega_y, T):
    """Return average Y Pauli measurement vs time t"""
    eOmega = get_omega(eDelta, eOmega_x, eOmega_y)
    eYt = (eDelta*eOmega_y - (eDelta*eOmega_y*np.cos(eOmega*t) - \
           eOmega*eOmega_x*np.sin(eOmega*t))) / eOmega**2 +0.1
    return eYt

def avg_Z(t, eDelta, eOmega_x, eOmega_y, T):
    """Return average Z Pauli measurement vs time t"""
    eOmega = get_omega(eDelta, eOmega_x, eOmega_y)
    eZt = (eDelta**2 + np.exp(-t/T)*(eOmega_x**2 + eOmega_y**2)*np.cos(eOmega*t)) / eOmega**2 
    return eZt

def rt_evol(ts, eDelta, eOmega_x, eOmega_y, T):
    """Stack average X,Y,Z Pauli measurements vertically."""
    return np.vstack([avg_X(ts, eDelta, eOmega_x, eOmega_y,T), \
                     avg_Y(ts, eDelta, eOmega_x, eOmega_y,T), \
                     avg_Z(ts, eDelta, eOmega_x, eOmega_y,T)])
    
def rt_flat(ts, eDelta, eOmega_x, eOmega_y, T):
    """Flatten X,Y,Z Pauli measurement data into 1D array."""
    return rt_evol(ts[0:len(ts)//3], eDelta, eOmega_x, eOmega_y, T).flatten()

def fit_rt_evol(ts, eXt, eYt, eZt, p0):
    """Use curve_fit to determine fit parameters of X,Y,Z Pauli measurements together."""
    rt_vec = np.asarray([eXt, eYt, eZt])
    
    return curve_fit(rt_flat, np.tile(ts, 3), rt_vec.flatten(), p0=p0, method='trf')

# %%
def get_omega_exc(eDelta, eOmega_x, eOmega_y):
    """Return \Omega from parameter arguments."""
    eOmega = np.sqrt(eDelta**2 + eOmega_x**2 + eOmega_y**2)
    return eOmega

def avg_X_exc(t, eDelta, eOmega_x, eOmega_y, T):
    """Return average X Pauli measurement vs time t"""
    eOmega = get_omega_exc(eDelta, eOmega_x, eOmega_y)
    eXt = (-eDelta*eOmega_x + np.exp(-t/T)*(eDelta*eOmega_x*np.cos(eOmega*t) + \
           eOmega*eOmega_y*np.sin(eOmega*t)))/ eOmega**2 
    return eXt

def avg_Y_exc(t, eDelta, eOmega_x, eOmega_y, T):
    """Return average Y Pauli measurement vs time t"""
    eOmega = get_omega_exc(eDelta, eOmega_x, eOmega_y)
    eYt = (eDelta*eOmega_y - eDelta*eOmega_y*np.cos(eOmega*t) - \
           eOmega*eOmega_x*np.sin(eOmega*t)) / eOmega**2 
    return eYt

def avg_Z_exc(t, eDelta, eOmega_x, eOmega_y, T):
    """Return average Z Pauli measurement vs time t"""
    eOmega = get_omega_exc(eDelta, eOmega_x, eOmega_y)
    eZt = (eDelta**2 + np.exp(-t/T)*(eOmega_x**2 + eOmega_y**2)*np.cos(eOmega*t)) / eOmega**2 
    return eZt

def rt_evol_exc(ts, eDelta, eOmega_x, eOmega_y, T):
    """Stack average X,Y,Z Pauli measurements vertically."""
    return np.vstack([avg_X_exc(ts, eDelta, eOmega_x, eOmega_y, T), \
                     avg_Y_exc(ts, eDelta, eOmega_x, eOmega_y, T), \
                     avg_Z_exc(ts, eDelta, eOmega_x, eOmega_y, T)])
    
def rt_flat_exc(ts, eDelta, eOmega_x, eOmega_y, T):
    """Flatten X,Y,Z Pauli measurement data into 1D array."""
    return rt_evol_exc(ts[0:len(ts)//3], eDelta, eOmega_x, eOmega_y, T).flatten()

def fit_rt_evol_exc(ts, eXt, eYt, eZt, p0):
    """Use curve_fit to determine fit parameters of X,Y,Z Pauli measurements together."""
    rt_vec = np.asarray([eXt, eYt, eZt])
    
    return curve_fit(rt_flat_exc, np.tile(ts, 3), rt_vec.flatten(), p0=p0, method='trf')

# %%
def get_interation_rates_MHz(ground_fit, excited_fit):
    """Determine interaction rates from fits to ground and excited control qubit data."""
    Delta0 = (ground_fit[0]/dt)/1e6
    Omega0_x = (ground_fit[1]/dt)/1e6
    Omega0_y = (ground_fit[2]/dt)/1e6
    Delta1 = (excited_fit[0]/dt)/1e6
    Omega1_x = (excited_fit[1]/dt)/1e6
    Omega1_y = (excited_fit[2]/dt)/1e6
    
    IX = 0.5*(Omega0_x + Omega1_x)

    IY = 0.5*(Omega0_y + Omega1_y)
    IZ = 0.5*(Delta0 + Delta1)
    ZX = 0.5*(Omega0_x - Omega1_x)
    ZY = 0.5*(Omega0_y - Omega1_y)
    ZZ = 0.5*(Delta0 - Delta1)
    
    return [[IX, IY, IZ], [ZX, ZY, ZZ]]

def plot_cr_ham_tomo(cr_amps, avg_t_c, ground_fit, excited_fit):
    """Plot Hamiltonian tomography data and curve fits with interaction rates."""
    coeffs = get_interation_rates_MHz(ground_fit, excited_fit)
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15,15), sharey = True)
    ax1.scatter(cr_times, avg_t_c[0,:].real, lw=3.0, color='blue', label='ctrl in |1>')
    # ax1.plot(cr_times, avg_X(cr_times, *ground_fit), lw=3.0, color='blue')
    ax1.scatter(cr_times, avg_t_c[1,:].real, lw=3.0, color='red', label='ctrl in |2>')
    # ax1.plot(cr_times, avg_X_exc(cr_times, *excited_fit), lw=3.0, color='red')
    ax1.set_ylabel('<X(t)>', fontsize=20)
    ax1.set_title('Pauli Expectation Value', fontsize=20)
    ax1.legend(loc=4, fontsize=14)
    ax2.scatter(cr_times, avg_t_c[2,:].real, lw=3.0, color='blue', label='ctrl in |1>')
    # ax2.plot(cr_times, avg_Y(cr_times, *ground_fit), lw=3.0, color='blue')
    ax2.scatter(cr_times, avg_t_c[3,:].real, lw=3.0, color='red', label='ctrl in |2>')
    # ax2.plot(cr_times, avg_Y_exc(cr_times, *excited_fit), lw=3.0, color='red')
    ax2.set_title('IX = %.3f MHz   IY = %.3f MHz   IZ = %.3f MHz' % \
              (coeffs[0][0], coeffs[0][1], coeffs[0][2]), fontsize=20)
    ax2.set_ylabel('<Y(t)>', fontsize=20)
    ax2.legend(loc=4, fontsize=14)
    ax3.scatter(cr_times, avg_t_c[4,:].real, lw=3.0, color='blue', label='ctrl in |1>')
    # ax3.plot(cr_times, avg_Z(cr_times, *ground_fit), lw=3.0, color='blue')
    ax3.scatter(cr_times, avg_t_c[5,:].real, lw=3.0, color='red', label='ctrl in |2>')
    # ax3.plot(cr_times, avg_Z_exc(cr_times, *excited_fit), lw=3.0, color='red')
    ax3.set_title('ZX = %.3f MHz   ZY = %.3f MHz   ZZ = %.3f MHz' % \
              (coeffs[1][0], coeffs[1][1], coeffs[1][2]), fontsize=20)
    ax3.set_ylabel('<Z(t)>', fontsize=20)
    ax3.set_xlabel('time (dt)', fontsize=20)
    ax3.legend(loc=4, fontsize=14)

# %%
ground_fit,_ = fit_rt_evol(cr_times, avg_t_c[0,:], avg_t_c[2,:], avg_t_c[4,:], p0=[-0.0002, 0.0002, 0.0000, 100])
excited_fit,_ = fit_rt_evol_exc(cr_times, avg_t_c[1,:], avg_t_c[3,:], avg_t_c[5,:], p0=[0.00002, 0.002, 0.002, 100])

print(ground_fit)
print(excited_fit)
plot_cr_ham_tomo(cr_times, avg_t_c, ground_fit, excited_fit)
# Out:
# [ 2.69001040e-03  2.84108290e-03 -6.61118906e-03  1.00001286e+02]
# [ 2.06435061e-02 -8.97063039e-03  9.68235790e-03  1.85157618e+02]

# %%
coeffs = get_interation_rates_MHz(ground_fit, excited_fit)
ZX_rate = coeffs[1][0]
ZY_rate = coeffs[1][1]
IX_rate = coeffs[0][0]
IY_rate = coeffs[0][1]
cr_phase = -np.arctan2(ZY_rate, ZX_rate)
cancellation_phase = -np.arctan2(IY_rate, IX_rate)
print(ZY_rate, ZX_rate, cr_phase)
print(IY_rate, IX_rate, cr_phase - cancellation_phase)
# Out:
# 3.7226321295693747 0.2858513385834874 -1.494159290057497
# 0.2958426829711873 0.6440292270710881 -1.0635470876869582

# %%
#0.9217258122678619: old cr_phase
# 3.7375591157055594: old cancellation phase
cr_phase = -0.57243347779
cancellation_phase = 2.67401202802

# %% [markdown]
# Cancellation Tones Calibration

# %%
cr_times = 16*np.linspace(0,120,16)
print(cr_times+cr_risefall*2*cr_sigma)
exp_cr_tomo_circs1, cr_scheds = build_cr_tomo_scheds(control_qubit, target_qubit, cr_times, cr_phase,0, cancellation_phase)

cr_scheds[20].draw()
# Out:
# [ 128.  224.  320.  416.  512.  608.  704.  800.  896.  992. 1088. 1184.
#  1280. 1376. 1472. 1568. 1664. 1760. 1856. 1952. 2048.]

# %%
exp_cr_tomo_circs2, cr_scheds = build_cr_tomo_scheds(control_qubit, target_qubit, cr_times, cr_phase, 0.05, cancellation_phase)
print(len(exp_cr_tomo_circs2))
cr_scheds[20].draw()
# Out:
# 126

# %%
# cancellation_job1 = backend.run(exp_cr_tomo_circs1, meas_level=1, meas_return = 'single', shots = 500)
# cancellation_job2 = backend.run(exp_cr_tomo_circs2, meas_level=1, meas_return = 'single', shots = 500)

# %%
cr_tomo_results = backend.retrieve_job('crsde0gy7jt0008006yg').result()

# %%
print(cr_times + 2*cr_risefall*cr_sigma)
# Out:
# [ 128.  336.  544.  752.  960. 1168. 1376. 1584. 1792. 2000. 2208. 2416.
#  2624. 2832. 3040. 3248.]

# %%
iq_data = cr_tomo_results.get_memory(2)[:,control_qubit] * scale_factor
plt.scatter(np.real(iq_data), np.imag(iq_data))

# %%
avg_t_c = np.zeros((6,len(cr_times)), dtype = complex)
cr_amp_data = []
# iq_data = cr_amp_results.get_memory(0)[:,2] * scale_factor
# print(iq_data)
classifier = qubit_classifiers[control_qubit]
expectation_vals = np.zeros((6, len(cr_times)))
for i in range(96):
    iq_data = cr_tomo_results.get_memory(i)[:,control_qubit] * scale_factor
    # iq_data2 = cr_tomo_results2.get_memory(i)[:,target_qubit] * scale_factor
    val = classifier.predict(reshape_complex_vec(iq_data))
    # val2 = classifier.predict(reshape_complex_vec(iq_data2))

    expectation = 0
    results = [0,0,0]
    for v in val:
        if v == 0:
            expectation += 1
            results[0]+=1
        if v == 1:
            expectation -= 1
            results[1]+=1
        if v == 2:
            # expectation -= 1
            results[2]+=1
    # for v in val2:
    #     if v == 0:
    #         expectation += 1
    #         results[0]+=1
    #     if v == 1:
    #         expectation += 1
    #         results[1]+=1
    #     if v == 2:
    #         expectation -= 1
    #         results[2]+=1
    # if i % 2 == 0:
    print(i//6, results, expectation/(512-results[2]))
    expectation_vals[i%6, i//6] = expectation/(512 - results[2])
    avg_t_c[i%6, i//6] = 1-sum(val)/1024
# Out:
# 0 [6, 462, 44] -0.9743589743589743
# 0 [495, 12, 5] 0.9526627218934911
# 0 [4, 467, 41] -0.9830148619957537
# 0 [494, 16, 2] 0.9372549019607843
# 0 [5, 473, 34] -0.9790794979079498
# 0 [495, 16, 1] 0.9373776908023483
# 1 [9, 466, 37] -0.9621052631578947
# 1 [492, 17, 3] 0.9332023575638507
# 1 [4, 473, 35] -0.9832285115303984
# 1 [493, 16, 3] 0.93713163064833
# 1 [8, 461, 43] -0.9658848614072495
# 1 [498, 14, 0] 0.9453125
# 2 [10, 459, 43] -0.9573560767590619
# 2 [500, 10, 2] 0.9607843137254902
# 2 [10, 476, 26] -0.9588477366255144
# 2 [487, 25, 0] 0.90234375
# 2 [14, 467, 31] -0.9417879417879418
# 2 [498, 13, 1] 0.949119373776908
# 3 [9, 469, 34] -0.9623430962343096
# 3 [490, 18, 4] 0.9291338582677166
# 3 [13, 461, 38] -0.9451476793248945
# 3 [491, 20, 1] 0.9217221135029354
# 3 [6, 476, 30] -0.975103734439834
# 3 [495, 15, 2] 0.9411764705882353
# 4 [11, 472, 29] -0.9544513457556936
# 4 [490, 15, 7] 0.9405940594059405
# 4 [14, 461, 37] -0.9410526315789474
# 4 [491, 18, 3] 0.9292730844793713
# 4 [9, 468, 35] -0.9622641509433962
# 4 [495, 14, 3] 0.9449901768172888
# 5 [10, 463, 39] -0.9577167019027484
# 5 [493, 16, 3] 0.93713163064833
# 5 [8, 471, 33] -0.9665970772442589
# 5 [499, 12, 1] 0.9530332681017613
# 5 [8, 467, 37] -0.9663157894736842
# 5 [499, 12, 1] 0.9530332681017613
# 6 [8, 466, 38] -0.9662447257383966
# 6 [499, 12, 1] 0.9530332681017613
# 6 [8, 466, 38] -0.9662447257383966
# 6 [484, 24, 4] 0.905511811023622
# 6 [8, 462, 42] -0.9659574468085106
# 6 [499, 12, 1] 0.9530332681017613
# 7 [5, 471, 36] -0.9789915966386554
# 7 [494, 17, 1] 0.9334637964774951
# 7 [19, 457, 36] -0.9201680672268907
# 7 [498, 11, 3] 0.9567779960707269
# 7 [8, 476, 28] -0.9669421487603306
# 7 [492, 19, 1] 0.9256360078277887
# 8 [12, 468, 32] -0.95
# 8 [493, 16, 3] 0.93713163064833
# 8 [13, 470, 29] -0.9461697722567288
# 8 [496, 16, 0] 0.9375
# 8 [11, 462, 39] -0.9534883720930233
# 8 [493, 18, 1] 0.9295499021526419
# 9 [11, 462, 39] -0.9534883720930233
# 9 [490, 21, 1] 0.9178082191780822
# 9 [11, 469, 32] -0.9541666666666667
# 9 [489, 19, 4] 0.9251968503937008
# 9 [9, 474, 29] -0.9627329192546584
# 9 [493, 15, 4] 0.9409448818897638
# 10 [9, 475, 28] -0.9628099173553719
# 10 [494, 17, 1] 0.9334637964774951
# 10 [11, 465, 36] -0.9537815126050421
# 10 [492, 17, 3] 0.9332023575638507
# 10 [14, 463, 35] -0.9412997903563941
# 10 [487, 25, 0] 0.90234375
# 11 [11, 477, 24] -0.9549180327868853
# 11 [497, 13, 2] 0.9490196078431372
# 11 [8, 464, 40] -0.9661016949152542
# 11 [496, 14, 2] 0.9450980392156862
# 11 [11, 472, 29] -0.9544513457556936
# 11 [483, 26, 3] 0.8978388998035364
# 12 [7, 473, 32] -0.9708333333333333
# 12 [490, 19, 3] 0.925343811394892
# 12 [11, 466, 35] -0.9538784067085954
# 12 [496, 13, 3] 0.9489194499017681
# 12 [12, 466, 34] -0.9497907949790795
# 12 [492, 18, 2] 0.9294117647058824
# 13 [12, 463, 37] -0.9494736842105264
# 13 [493, 18, 1] 0.9295499021526419
# 13 [10, 476, 26] -0.9588477366255144
# 13 [498, 13, 1] 0.949119373776908
# 13 [8, 478, 26] -0.9670781893004116
# 13 [480, 27, 5] 0.893491124260355
# 14 [11, 473, 28] -0.9545454545454546
# 14 [486, 24, 2] 0.9058823529411765
# 14 [12, 472, 28] -0.9504132231404959
# 14 [498, 13, 1] 0.949119373776908
# 14 [8, 474, 30] -0.966804979253112
# 14 [498, 11, 3] 0.9567779960707269
# 15 [14, 468, 30] -0.941908713692946
# 15 [497, 14, 1] 0.9452054794520548
# 15 [19, 466, 27] -0.9216494845360824
# 15 [493, 18, 1] 0.9295499021526419
# 15 [10, 464, 38] -0.9578059071729957
# 15 [494, 16, 2] 0.9372549019607843
